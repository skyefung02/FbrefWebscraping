# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd 

html_salah_summary_2324 = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/Mohamed-Salah-Match-Logs').text
soup_summary = BeautifulSoup(html_salah_summary_2324, 'lxml')
salah_data_summary = soup_summary.find('tbody')

# %%
def get_url_final(code, year_range, category, player):
    base_url = 'https://fbref.com/en/players/{}/matchlogs/{}/c9/{}/{}-Match-Logs'
    url = base_url.format(year_range, category)
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml')
    html_filtered = soup.find('tbody')
    return(html_filtered)

# %%
#getting data function 
# def get_dat(dat, col):
#     coldat = []
#     for element in dat.find_all('td', attrs ={'data-stat': col}):
#         coldat.append(element.text)
#     coldat = [item for item in coldat if item != '']
#     return (coldat)    
# def get_date(dat, col):
#     coldat = []
#     for element in dat.find_all('th', attrs ={'data-stat': col}):
#         coldat.append(element.text)
#     coldat = [item for item in coldat if item != '']
#     return (coldat)   
# def get_matchweek(dat, col):
#     coldat = []
#     for element in dat.find_all('td', attrs = {'data-stat': col}):
#         coldat.append(element.text)
#     coldat = [item for item in coldat if item != '']
#     coldat = [coldat.replace('Matchweek ', '') for coldat in coldat]
#     return(coldat)


#updated functions
def get_dat(dat, col):
    coldat = []
    for row in dat.find_all('tr'):
        if not row.attrs:
            coldat.append(row.find('td', {'data-stat': col}).text)
    return (coldat)   

def get_date(dat, col):
    coldat = []
    for row in dat.find_all('tr'):
        if not row.attrs:
            coldat.append(row.find('th', {'data-stat': col}).text)
    return (coldat)   

def get_matchweek(dat, col):
    coldat = []
    for row in dat.find_all('tr'):
        if not row.attrs:
            coldat.append(row.find('td', {'data-stat': col}).text)
    coldat = [coldat.replace('Matchweek ', '') for coldat in coldat]
    return(coldat)

# %%
#getting the data for the necessary columns

#misc data 
date = get_date(salah_data_summary, 'date')
day = get_dat(salah_data_summary,'dayofweek')
matchweek = get_matchweek(salah_data_summary, 'round')
venue = get_dat(salah_data_summary, 'venue')
result = get_dat(salah_data_summary, 'result')
team = get_dat(salah_data_summary, 'team')
opponent = get_dat(salah_data_summary, 'opponent')
start = get_dat(salah_data_summary, 'game_started')
position = get_dat(salah_data_summary, 'position')
mins = get_dat(salah_data_summary, 'minutes')

#performance data
goals = get_dat(salah_data_summary, 'goals')
assist = get_dat(salah_data_summary, 'assists')
pen_goals = get_dat(salah_data_summary, 'pens_made')
pen_attempted = get_dat(salah_data_summary, 'pens_att')
shots = get_dat(salah_data_summary, 'shots')
sot = get_dat(salah_data_summary, 'shots_on_target')
yellow = get_dat(salah_data_summary, 'cards_yellow')
red = get_dat(salah_data_summary, 'cards_red')
touches = get_dat(salah_data_summary, 'touches')
tackles = get_dat(salah_data_summary, 'tackles')
interceptions = get_dat(salah_data_summary, 'interceptions')
blocks = get_dat(salah_data_summary, 'blocks')

#expected performance metrics
xg = get_dat(salah_data_summary, 'xg')
npxg = get_dat(salah_data_summary, 'npxg')
xag = get_dat(salah_data_summary, 'xg_assist')

#shot creating actions
sca = get_dat(salah_data_summary, 'sca')
gca = get_dat(salah_data_summary, 'gca')

#passes
passes_completed = get_dat(salah_data_summary, 'passes_completed')
passes_attempted = get_dat(salah_data_summary, 'passes')
prg_passes = get_dat(salah_data_summary, 'progressive_passes')

#carries 
carries = get_dat(salah_data_summary, 'carries')
prg_carries = get_dat(salah_data_summary, 'progressive_carries')

#take-ons
takeon_att = get_dat(salah_data_summary, 'take_ons')
takeon_suc = get_dat(salah_data_summary, 'take_ons_won')

# %%
#this to get salah's passing data 
html_salah_2324_passing = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/passing/Mohamed-Salah-Match-Logs').text
soup_passing = BeautifulSoup(html_salah_2324_passing, 'lxml')
salah_data_passing = soup_passing.find('tbody')

#total
pass_distance = get_dat(salah_data_passing, 'passes_total_distance')
prg_pass_distance = get_dat(salah_data_passing, 'passes_progressive_distance')

#short
short_pass_completed = get_dat(salah_data_passing, 'passes_completed_short')
short_pass_attempted = get_dat(salah_data_passing, 'passes_short')

#medium 
med_pass_completed = get_dat(salah_data_passing, 'passes_completed_medium')
med_pass_attempted = get_dat(salah_data_passing, 'passes_medium')

#long
long_pass_completed = get_dat(salah_data_passing, 'passes_completed_long')
long_pass_attempted = get_dat(salah_data_passing, 'passes_long')

#misc
xa = get_dat(salah_data_passing, 'pass_xa')
keypass = get_dat(salah_data_passing, 'assisted_shots')
finalthird_pass = get_dat(salah_data_passing, 'passes_into_final_third')
penaltyarea_pass = get_dat(salah_data_passing, 'passes_into_penalty_area')
penaltyarea_cross = get_dat(salah_data_passing, 'crosses_into_penalty_area')

# %%
#this to get salah's passing types data 
html_salah_2324_passingtypes = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/passing_types/Mohamed-Salah-Match-Logs').text
soup_passingtypes = BeautifulSoup(html_salah_2324_passingtypes, 'lxml')
salah_data_passingtypes = soup_passingtypes.find('tbody')

live_pass = get_dat(salah_data_passingtypes, 'passes_live')
dead_pass = get_dat(salah_data_passingtypes, 'passes_dead')
freekick_pass = get_dat(salah_data_passingtypes, 'passes_free_kicks')
through_balls = get_dat(salah_data_passingtypes, 'through_balls')
switches = get_dat(salah_data_passingtypes, 'passes_switches')
crosses = get_dat(salah_data_passingtypes, 'crosses')
throwin = get_dat(salah_data_passingtypes, 'throw_ins')
corners = get_dat(salah_data_passingtypes, 'corner_kicks')
offside_pass = get_dat(salah_data_passingtypes, 'passes_offsides')

# %%
#this to get salah's gca data 
html_salah_2324_gca = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/gca/Mohamed-Salah-Match-Logs').text
soup_gca = BeautifulSoup(html_salah_2324_gca, 'lxml')
salah_data_gca = soup_gca.find('tbody')

#sca types 
live_sca = get_dat(salah_data_gca, 'sca_passes_live')
deadball_sca = get_dat(salah_data_gca, 'sca_passes_dead')
takeons_sca = get_dat(salah_data_gca, 'sca_take_ons')
shots_sca = get_dat(salah_data_gca, 'sca_shots')
fouls_sca = get_dat(salah_data_gca, 'sca_fouled')
defense_sca = get_dat(salah_data_gca, 'sca_defense')

#gca types 
live_gca = get_dat(salah_data_gca, 'gca_passes_live')
deadball_gca = get_dat(salah_data_gca, 'gca_passes_dead')
takeons_gca = get_dat(salah_data_gca, 'gca_take_ons')
shots_gca = get_dat(salah_data_gca, 'gca_shots')
fouls_gca = get_dat(salah_data_gca, 'gca_fouled')
defense_gca = get_dat(salah_data_gca, 'gca_defense')

# %%
#this is to get salah's defensive data
html_salah_2324_defense = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/defense/Mohamed-Salah-Match-Logs').text
soup_defense = BeautifulSoup(html_salah_2324_defense, 'lxml')
salah_data_defense = soup_defense.find('tbody')

#tackles
tackles_won = get_dat(salah_data_defense,'tackles_won')
tackles_def = get_dat(salah_data_defense, 'tackles_def_3rd')
tackles_mid = get_dat(salah_data_defense, 'tackles_mid_3rd')
tackles_att = get_dat(salah_data_defense, 'tackles_att_3rd')

#challenges 
dribblers_tackled = get_dat(salah_data_defense, 'challenge_tackles')
dribbles_challenged = get_dat(salah_data_defense, 'challenges')
challenges_lost = get_dat(salah_data_defense, 'challenges_lost')

#blocks 
shots_blocked = get_dat(salah_data_defense, 'blocked_shots')
pass_blocked = get_dat(salah_data_defense, 'blocked_passes')
clearances = get_dat(salah_data_defense, 'clearances')
def_errors = get_dat(salah_data_defense, 'errors')

# %%
#this is to get salah's possession data
html_salah_2324_possession = requests.get('https://fbref.com/en/players/e342ad68/matchlogs/2023-2024/c9/possession/Mohamed-Salah-Match-Logs').text
soup_possession = BeautifulSoup(html_salah_2324_possession, 'lxml')
salah_data_possession = soup_possession.find('tbody')

#touches 
def_penarea_touches = get_dat(salah_data_possession, 'touches_def_pen_area')
def_third_touches = get_dat(salah_data_possession, 'touches_def_3rd')
mid_third_touches = get_dat(salah_data_possession, 'touches_mid_3rd')
att_third_touches = get_dat(salah_data_possession, 'touches_att_3rd')
pen_area_touches = get_dat(salah_data_possession, 'touches_att_pen_area')

#carries
carry_distance = get_dat(salah_data_possession, 'carries_distance')
prg_carry_distance = get_dat(salah_data_possession, 'carries_progressive_distance')
final_third_carries = get_dat(salah_data_possession, 'carries_into_final_third')
pen_area_carries = get_dat(salah_data_possession, 'carries_into_penalty_area')
miscontrols = get_dat(salah_data_possession, 'miscontrols')
dispossesed = get_dat(salah_data_possession, 'dispossessed')

#receiving 
pass_received = get_dat(salah_data_possession, 'passes_received')
prg_pass_received = get_dat(salah_data_possession, 'progressive_passes_received')

# %%
#putting all of the arrays into a pd dataframe
salah2324_df = pd.DataFrame({
    'Date': date,
    'Day': day,
    'Matchweek': matchweek,
    'Venue': venue,
    'Result': result,
    'Team': team,
    'Opponent': opponent, 
    'Start': start, 
    'Position': position,
    'Minutes Played': mins, 
    'Goals': goals, 
    'Assists': assist, 
    'Penalties Scored': pen_goals, 
    'Penalties Attempted': pen_attempted, 
    'Shots': shots, 
    'Shots on Target': sot, 
    'Yellow Cards': yellow, 
    'Red Cards': red, 
    'Touches': touches, 
    'Tackles': tackles,
    'Interceptions': interceptions, 
    'Blocks': blocks, 
    'xG': xg,
    'npxG': npxg,
    'xAG': xag, 
    'Shot Creating Actions': sca, 
    'Goal Creating Actions': gca, 
    'Passes Completed': passes_completed, 
    'Passes Attempted': passes_attempted, 
    'Progressive Passes': prg_passes,
    'Carries': carries, 
    'Progressive Carries': prg_carries, 
    'Take-ons Attempted': takeon_att, 
    'Successful Take-ons': takeon_suc,
    
    'Passing Distance': pass_distance, 
    'Progressive Passing Distance': prg_pass_distance,
    'Short Passes Completed' : short_pass_completed,
    'Short Passes Attempted': short_pass_attempted,
    'Medium Passes Completed': med_pass_completed,
    'Medium Passes Attempted': med_pass_attempted,
    'Long Passes Completed': long_pass_completed,
    'Long Passes Attempted': long_pass_attempted,
    'Expected Assists': xa,
    'Key Passes': keypass,
    'Passes into Final Third': finalthird_pass,
    'Passes into Penalty Area': penaltyarea_pass,
    'Crosses into Penalty Area': penaltyarea_cross,
    
    'Live Pass': live_pass,
    'Dead Pass': dead_pass,
    'Free Kick Pass': freekick_pass,
    'Through Balls': through_balls,
    'Switches': switches,
    'Crosses': crosses,
    'Throw Ins Taken': throwin,
    'Corners Taken': corners,
    'Passes Offside': offside_pass,
    
    'Live SCA': live_sca,
    'Deadball SCA': deadball_sca,
    'Take-on SCA': takeons_sca,
    'Shot SCA': shots_sca,
    'Foul SCA': fouls_sca,
    'Defense SCA': defense_sca,
    
    'Live GCA': live_gca,
    'Deadball GCA': deadball_gca,
    'Take-on GCA': takeons_gca,
    'Shot GCA': shots_gca,
    'Foul GCA': fouls_gca,
    'Defense GCA': defense_gca,
    
    'Tackles Won': tackles_won,
    'Defensive Third Tackles': tackles_def,
    'Middle Third Tackles': tackles_mid,
    'Attacking Third Tackles': tackles_att,
    'Dribblers Tackled': dribblers_tackled,
    'Dribblers Tackled Attempts': dribbles_challenged,
    'Challenges Lost': challenges_lost,
    'Shots Blocked': shots_blocked,
    'Passes Blocked': pass_blocked,
    'Clearances': clearances,
    'Defensive Errors': def_errors,
    
    'Defensive Penalty Area Touches': def_penarea_touches,
    'Defensive Third Touches': def_third_touches,
    'Middle Third Touches': mid_third_touches,
    'Attacking Third Touches': att_third_touches,
    'Penalty Area Touches': pen_area_touches,
    'Carry Distance': carry_distance,
    'Progressive Carry Distance': prg_carry_distance,
    'Final Third Carries': final_third_carries,
    'Carries into Penalty Area': pen_area_carries,
    'Miscontrols': miscontrols,
    'Dispossessed': dispossesed,
    'Passes Received': pass_received,
    'Progressive Passes Received': prg_pass_received
})

# %%
#changing the data types 
salah2324_df = salah2324_df.astype({
    'Date': 'datetime64[ns]',
    'Day': 'object',
    'Matchweek': 'int64',
    'Venue': 'object',
    'Result': 'object',
    'Team': 'object',
    'Opponent': 'object', 
    'Start': 'object', 
    'Position': 'object',
    'Minutes Played': 'int64', 
    'Goals': 'int64', 
    'Assists': 'int64', 
    'Penalties Scored': 'int64', 
    'Penalties Attempted': 'int64', 
    'Shots': 'int64', 
    'Shots on Target': 'int64', 
    'Yellow Cards': 'int64', 
    'Red Cards': 'int64', 
    'Touches': 'int64', 
    'Tackles': 'int64',
    'Interceptions': 'int64', 
    'Blocks': 'int64', 
    'xG': 'float64',
    'npxG': 'float64',
    'xAG': 'float64', 
    'Shot Creating Actions': 'int64', 
    'Goal Creating Actions': 'int64', 
    'Passes Completed': 'int64', 
    'Passes Attempted': 'int64', 
    'Progressive Passes': 'int64',
    'Carries': 'int64', 
    'Progressive Carries': 'int64', 
    'Take-ons Attempted': 'int64', 
    'Successful Take-ons': 'int64',
    
    'Short Passes Completed' : 'int64',
    'Short Passes Attempted': 'int64',
    'Medium Passes Completed': 'int64',
    'Medium Passes Attempted': 'int64',
    'Long Passes Completed': 'int64',
    'Long Passes Attempted': 'int64',
    'Expected Assists': 'float64',
    'Key Passes': 'int64',
    'Passes into Final Third': 'int64',
    'Passes into Penalty Area': 'int64',
    'Crosses into Penalty Area': 'int64',
    
    'Live Pass': 'int64',
    'Dead Pass': 'int64',
    'Free Kick Pass': 'int64',
    'Through Balls': 'int64',
    'Switches': 'int64',
    'Crosses': 'int64',
    'Throw Ins Taken': 'int64',
    'Corners Taken': 'int64',
    'Passes Offside': 'int64',
    
    'Live SCA': 'int64',
    'Deadball SCA': 'int64',
    'Take-on SCA': 'int64',
    'Shot SCA': 'int64',
    'Foul SCA': 'int64',
    'Defense SCA': 'int64',
    
    'Live GCA': 'int64',
    'Deadball GCA': 'int64',
    'Take-on GCA': 'int64',
    'Shot GCA': 'int64',
    'Foul GCA': 'int64',
    'Defense GCA': 'int64',
    
    'Tackles Won': 'int64',
    'Defensive Third Tackles': 'int64',
    'Middle Third Tackles': 'int64',
    'Attacking Third Tackles': 'int64',
    'Dribblers Tackled': 'int64',
    'Dribblers Tackled Attempts': 'int64',
    'Challenges Lost': 'int64',
    'Shots Blocked': 'int64',
    'Passes Blocked': 'int64',
    'Clearances': 'int64',
    'Defensive Errors': 'int64',
    
    'Defensive Penalty Area Touches': 'int64',
    'Defensive Third Touches': 'int64',
    'Middle Third Touches': 'int64',
    'Attacking Third Touches': 'int64',
    'Penalty Area Touches': 'int64',
    'Carry Distance': 'float64',
    'Progressive Carry Distance': 'float64',
    'Final Third Carries': 'int64',
    'Carries into Penalty Area': 'int64',
    'Miscontrols': 'int64',
    'Dispossessed': 'int64',
    'Passes Received': 'int64',
    'Progressive Passes Received': 'int64'
})

#changing the date column format 
salah2324_df['Date'] = salah2324_df['Date'].dt.date

# %%
#now we want to get the fpl data 
salah_2324_fpldf= pd.read_csv("https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/players/Mohamed_Salah_308/gw.csv")

#some of the columns are duplicated (from the webscraped data), so we want to remove these 
salah_2324_fpldf = salah_2324_fpldf.drop(['assists', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'fixture',
                                          'goals_conceded', 'goals_scored', 'penalties_missed', 'penalties_saved', 'red_cards'
                                          ,'team_a_score', 'team_h_score', 'was_home', 'yellow_cards', 'element', 'opponent_team'], axis=1)

#we now want to change the 'kickoff time' feature into a datetime object 
salah_2324_fpldf['kickoff_time'] = pd.to_datetime(salah_2324_fpldf['kickoff_time'])

#creating new column, which is just the kickoff date 
salah_2324_fpldf['kickoff_date'] = salah_2324_fpldf['kickoff_time'].dt.date

# %%
#finally, we want to combine the two dataframes together, inner join allows us to only keep the rows that are relevant 
salah_2324_finaldf = pd.merge(salah2324_df, salah_2324_fpldf, left_on='Date', right_on='kickoff_date', how='inner')

# %%
#just saving the dataframe as a csv, so we don't have to run the above code again
salah_2324_finaldf.to_csv('salah_2324_data.csv', index = False)

# %%
#this function just gets the html code that we need to scrape for data 
def get_url(year_range, category):
    base_url = 'https://fbref.com/en/players/e342ad68/matchlogs/{}/c9/{}/Mohamed-Salah-Match-Logs'
    url = base_url.format(year_range, category)
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml')
    html_filtered = soup.find('tbody')
    return(html_filtered)

# %%
#now, we want to see if we can write a function that gives us salah's 22/23 season data

def get_salah_data(year_range, fpl_link):
    data_summary = get_url(year_range, '')
    data_passing = get_url(year_range, 'passing')
    data_passingtype = get_url(year_range, 'passing_types')
    data_gca = get_url(year_range, 'gca')
    data_defense = get_url(year_range, 'defense')
    data_possession = get_url(year_range, 'possession')
    
    ################################################################
    #getting the data for the necessary columns
    
    ##### summary data #####
    #misc data 
    date = get_date(data_summary, 'date')
    day = get_dat(data_summary,'dayofweek')
    matchweek = get_matchweek(data_summary, 'round')
    venue = get_dat(data_summary, 'venue')
    result = get_dat(data_summary, 'result')
    team = get_dat(data_summary, 'team')
    opponent = get_dat(data_summary, 'opponent')
    start = get_dat(data_summary, 'game_started')
    position = get_dat(data_summary, 'position')
    mins = get_dat(data_summary, 'minutes')

    #performance data
    goals = get_dat(data_summary, 'goals')
    assist = get_dat(data_summary, 'assists')
    pen_goals = get_dat(data_summary, 'pens_made')
    pen_attempted = get_dat(data_summary, 'pens_att')
    shots = get_dat(data_summary, 'shots')
    sot = get_dat(data_summary, 'shots_on_target')
    yellow = get_dat(data_summary, 'cards_yellow')
    red = get_dat(data_summary, 'cards_red')
    touches = get_dat(data_summary, 'touches')
    tackles = get_dat(data_summary, 'tackles')
    interceptions = get_dat(data_summary, 'interceptions')
    blocks = get_dat(data_summary, 'blocks')

    #expected performance metrics
    xg = get_dat(data_summary, 'xg')
    npxg = get_dat(data_summary, 'npxg')
    xag = get_dat(data_summary, 'xg_assist')

    #shot creating actions
    sca = get_dat(data_summary, 'sca')
    gca = get_dat(data_summary, 'gca')

    #passes
    passes_completed = get_dat(data_summary, 'passes_completed')
    passes_attempted = get_dat(data_summary, 'passes')
    prg_passes = get_dat(data_summary, 'progressive_passes')

    #carries 
    carries = get_dat(data_summary, 'carries')
    prg_carries = get_dat(data_summary, 'progressive_carries')

    #take-ons
    takeon_att = get_dat(data_summary, 'take_ons')
    takeon_suc = get_dat(data_summary, 'take_ons_won')
    
    ##### passing data #####
    #total
    pass_distance = get_dat(data_passing, 'passes_total_distance')
    prg_pass_distance = get_dat(data_passing, 'passes_progressive_distance')

    #short
    short_pass_completed = get_dat(data_passing, 'passes_completed_short')
    short_pass_attempted = get_dat(data_passing, 'passes_short')

    #medium 
    med_pass_completed = get_dat(data_passing, 'passes_completed_medium')
    med_pass_attempted = get_dat(data_passing, 'passes_medium')

    #long
    long_pass_completed = get_dat(data_passing, 'passes_completed_long')
    long_pass_attempted = get_dat(data_passing, 'passes_long')

    #misc
    xa = get_dat(data_passing, 'pass_xa')
    keypass = get_dat(data_passing, 'assisted_shots')
    finalthird_pass = get_dat(data_passing, 'passes_into_final_third')
    penaltyarea_pass = get_dat(data_passing, 'passes_into_penalty_area')
    penaltyarea_cross = get_dat(data_passing, 'crosses_into_penalty_area')
    
    
    ##### passing types data #####
    live_pass = get_dat(data_passingtype, 'passes_live')
    dead_pass = get_dat(data_passingtype, 'passes_dead')
    freekick_pass = get_dat(data_passingtype, 'passes_free_kicks')
    through_balls = get_dat(data_passingtype, 'through_balls')
    switches = get_dat(data_passingtype, 'passes_switches')
    crosses = get_dat(data_passingtype, 'crosses')
    throwin = get_dat(data_passingtype, 'throw_ins')
    corners = get_dat(data_passingtype, 'corner_kicks')
    offside_pass = get_dat(data_passingtype, 'passes_offsides')
    
    
    ##### gca data #####
    #sca types 
    live_sca = get_dat(data_gca, 'sca_passes_live')
    deadball_sca = get_dat(data_gca, 'sca_passes_dead')
    takeons_sca = get_dat(data_gca, 'sca_take_ons')
    shots_sca = get_dat(data_gca, 'sca_shots')
    fouls_sca = get_dat(data_gca, 'sca_fouled')
    defense_sca = get_dat(data_gca, 'sca_defense')

    #gca types 
    live_gca = get_dat(data_gca, 'gca_passes_live')
    deadball_gca = get_dat(data_gca, 'gca_passes_dead')
    takeons_gca = get_dat(data_gca, 'gca_take_ons')
    shots_gca = get_dat(data_gca, 'gca_shots')
    fouls_gca = get_dat(data_gca, 'gca_fouled')
    defense_gca = get_dat(data_gca, 'gca_defense')
    
    
    ##### defensive data ######
    #tackles
    tackles_won = get_dat(data_defense,'tackles_won')
    tackles_def = get_dat(data_defense, 'tackles_def_3rd')
    tackles_mid = get_dat(data_defense, 'tackles_mid_3rd')
    tackles_att = get_dat(data_defense, 'tackles_att_3rd')

    #challenges 
    dribblers_tackled = get_dat(data_defense, 'challenge_tackles')
    dribbles_challenged = get_dat(data_defense, 'challenges')
    challenges_lost = get_dat(data_defense, 'challenges_lost')

    #blocks 
    shots_blocked = get_dat(data_defense, 'blocked_shots')
    pass_blocked = get_dat(data_defense, 'blocked_passes')
    clearances = get_dat(data_defense, 'clearances')
    def_errors = get_dat(data_defense, 'errors')
    
    
    ##### possession data #####
    #touches 
    def_penarea_touches = get_dat(data_possession, 'touches_def_pen_area')
    def_third_touches = get_dat(data_possession, 'touches_def_3rd')
    mid_third_touches = get_dat(data_possession, 'touches_mid_3rd')
    att_third_touches = get_dat(data_possession, 'touches_att_3rd')
    pen_area_touches = get_dat(data_possession, 'touches_att_pen_area')

    #carries
    carry_distance = get_dat(data_possession, 'carries_distance')
    prg_carry_distance = get_dat(data_possession, 'carries_progressive_distance')
    final_third_carries = get_dat(data_possession, 'carries_into_final_third')
    pen_area_carries = get_dat(data_possession, 'carries_into_penalty_area')
    miscontrols = get_dat(data_possession, 'miscontrols')
    dispossesed = get_dat(data_possession, 'dispossessed')

    #receiving 
    pass_received = get_dat(data_possession, 'passes_received')
    prg_pass_received = get_dat(data_possession, 'progressive_passes_received')


    ###########################################################
    #creating dataframe
    df = pd.DataFrame({
        'Date': date,
        'Day': day,
        'Matchweek': matchweek,
        'Venue': venue,
        'Result': result,
        'Team': team,
        'Opponent': opponent, 
        'Start': start, 
        'Position': position,
        'Minutes Played': mins, 
        'Goals': goals, 
        'Assists': assist, 
        'Penalties Scored': pen_goals, 
        'Penalties Attempted': pen_attempted, 
        'Shots': shots, 
        'Shots on Target': sot, 
        'Yellow Cards': yellow, 
        'Red Cards': red, 
        'Touches': touches, 
        'Tackles': tackles,
        'Interceptions': interceptions, 
        'Blocks': blocks, 
        'xG': xg,
        'npxG': npxg,
        'xAG': xag, 
        'Shot Creating Actions': sca, 
        'Goal Creating Actions': gca, 
        'Passes Completed': passes_completed, 
        'Passes Attempted': passes_attempted, 
        'Progressive Passes': prg_passes,
        'Carries': carries, 
        'Progressive Carries': prg_carries, 
        'Take-ons Attempted': takeon_att, 
        'Successful Take-ons': takeon_suc,
        
        'Passing Distance': pass_distance, 
        'Progressive Passing Distance': prg_pass_distance,
        'Short Passes Completed' : short_pass_completed,
        'Short Passes Attempted': short_pass_attempted,
        'Medium Passes Completed': med_pass_completed,
        'Medium Passes Attempted': med_pass_attempted,
        'Long Passes Completed': long_pass_completed,
        'Long Passes Attempted': long_pass_attempted,
        'Expected Assists': xa,
        'Key Passes': keypass,
        'Passes into Final Third': finalthird_pass,
        'Passes into Penalty Area': penaltyarea_pass,
        'Crosses into Penalty Area': penaltyarea_cross,
    
        'Live Pass': live_pass,
        'Dead Pass': dead_pass,
        'Free Kick Pass': freekick_pass,
        'Through Balls': through_balls,
        'Switches': switches,
        'Crosses': crosses,
        'Throw Ins Taken': throwin,
        'Corners Taken': corners,
        'Passes Offside': offside_pass,
    
        'Live SCA': live_sca,
        'Deadball SCA': deadball_sca,
        'Take-on SCA': takeons_sca,
        'Shot SCA': shots_sca,
        'Foul SCA': fouls_sca,
        'Defense SCA': defense_sca,
    
        'Live GCA': live_gca,
        'Deadball GCA': deadball_gca,
        'Take-on GCA': takeons_gca,
        'Shot GCA': shots_gca,
        'Foul GCA': fouls_gca,
        'Defense GCA': defense_gca,
    
        'Tackles Won': tackles_won,
        'Defensive Third Tackles': tackles_def,
        'Middle Third Tackles': tackles_mid,
        'Attacking Third Tackles': tackles_att,
        'Dribblers Tackled': dribblers_tackled,
        'Dribblers Tackled Attempts': dribbles_challenged,
        'Challenges Lost': challenges_lost,
        'Shots Blocked': shots_blocked,
        'Passes Blocked': pass_blocked,
        'Clearances': clearances,
        'Defensive Errors': def_errors,
    
        'Defensive Penalty Area Touches': def_penarea_touches,
        'Defensive Third Touches': def_third_touches,
        'Middle Third Touches': mid_third_touches,
        'Attacking Third Touches': att_third_touches,
        'Penalty Area Touches': pen_area_touches,
        'Carry Distance': carry_distance,
        'Progressive Carry Distance': prg_carry_distance,
        'Final Third Carries': final_third_carries,
        'Carries into Penalty Area': pen_area_carries,
        'Miscontrols': miscontrols,
        'Dispossessed': dispossesed,
        'Passes Received': pass_received,
        'Progressive Passes Received': prg_pass_received
    })
    
    #modifying data types
    df = df.astype({
        'Date': 'datetime64[ns]',
        'Day': 'object',
        'Matchweek': 'int64',
        'Venue': 'object',
        'Result': 'object',
        'Team': 'object',
        'Opponent': 'object', 
        'Start': 'object', 
        'Position': 'object',
        'Minutes Played': 'int64', 
        'Goals': 'int64', 
        'Assists': 'int64', 
        'Penalties Scored': 'int64', 
        'Penalties Attempted': 'int64', 
        'Shots': 'int64', 
        'Shots on Target': 'int64', 
        'Yellow Cards': 'int64', 
        'Red Cards': 'int64', 
        'Touches': 'int64', 
        'Tackles': 'int64',
        'Interceptions': 'int64', 
        'Blocks': 'int64', 
        'xG': 'float64',
        'npxG': 'float64',
        'xAG': 'float64', 
        'Shot Creating Actions': 'int64', 
        'Goal Creating Actions': 'int64', 
        'Passes Completed': 'int64', 
        'Passes Attempted': 'int64', 
        'Progressive Passes': 'int64',
        'Carries': 'int64', 
        'Progressive Carries': 'int64', 
        'Take-ons Attempted': 'int64', 
        'Successful Take-ons': 'int64',
        
        'Short Passes Completed' : 'int64',
        'Short Passes Attempted': 'int64',
        'Medium Passes Completed': 'int64',
        'Medium Passes Attempted': 'int64',
        'Long Passes Completed': 'int64',
        'Long Passes Attempted': 'int64',
        'Expected Assists': 'float64',
        'Key Passes': 'int64',
        'Passes into Final Third': 'int64',
        'Passes into Penalty Area': 'int64',
        'Crosses into Penalty Area': 'int64',
    
        'Live Pass': 'int64',
        'Dead Pass': 'int64',
        'Free Kick Pass': 'int64',
        'Through Balls': 'int64',
        'Switches': 'int64',
        'Crosses': 'int64',
        'Throw Ins Taken': 'int64',
        'Corners Taken': 'int64',
        'Passes Offside': 'int64',
    
        'Live SCA': 'int64',
        'Deadball SCA': 'int64',
        'Take-on SCA': 'int64',
        'Shot SCA': 'int64',
        'Foul SCA': 'int64',
        'Defense SCA': 'int64',
    
        'Live GCA': 'int64',
        'Deadball GCA': 'int64',
        'Take-on GCA': 'int64',
        'Shot GCA': 'int64',
        'Foul GCA': 'int64',
        'Defense GCA': 'int64',
    
        'Tackles Won': 'int64',
        'Defensive Third Tackles': 'int64',
        'Middle Third Tackles': 'int64',
        'Attacking Third Tackles': 'int64',
        'Dribblers Tackled': 'int64',
        'Dribblers Tackled Attempts': 'int64',
        'Challenges Lost': 'int64',
        'Shots Blocked': 'int64',
        'Passes Blocked': 'int64',
        'Clearances': 'int64',
        'Defensive Errors': 'int64',
    
        'Defensive Penalty Area Touches': 'int64',
        'Defensive Third Touches': 'int64',
        'Middle Third Touches': 'int64',
        'Attacking Third Touches': 'int64',
        'Penalty Area Touches': 'int64',
        'Carry Distance': 'float64',
        'Progressive Carry Distance': 'float64',
        'Final Third Carries': 'int64',
        'Carries into Penalty Area': 'int64',
        'Miscontrols': 'int64',
        'Dispossessed': 'int64',
        'Passes Received': 'int64',
        'Progressive Passes Received': 'int64'
    })
    
    #changing date column data type 
    df['Date'] = df['Date'].dt.date
    
    ###############################################################################
    
    #now we want to get the fpl data 
    fpldf= pd.read_csv(fpl_link)

    #some of the columns are duplicated (from the webscraped data), so we want to remove these 
    fpldf = fpldf.drop(['assists', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'fixture',
                                          'goals_conceded', 'goals_scored', 'penalties_missed', 'penalties_saved', 'red_cards'
                                          ,'team_a_score', 'team_h_score', 'was_home', 'yellow_cards', 'element', 'opponent_team', 'starts'
                                          ,'expected_goals_conceded'], axis=1, 
                       errors = 'ignore')

    #we now want to change the 'kickoff time' feature into a datetime object 
    fpldf['kickoff_time'] = pd.to_datetime(fpldf['kickoff_time'])

    #creating new column, which is just the kickoff date 
    fpldf['kickoff_date'] = fpldf['kickoff_time'].dt.date
    
    finaldf = pd.merge(df, fpldf, left_on='Date', right_on='kickoff_date', how='inner')
    
    return(finaldf)

# %%
salah_2324_finaldf = get_salah_data('2023-2024', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/players/Mohamed_Salah_308/gw.csv")
salah_2324_finaldf.to_csv('salah_2324_data.csv', index = False)

# %%
salah_2223_finaldf = get_salah_data('2022-2023', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2022-23/players/Mohamed_Salah_283/gw.csv")
salah_2223_finaldf.to_csv('salah_2223_data.csv', index = False)

# %%
salah_2122_finaldf = get_salah_data('2021-2022', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2021-22/players/Mohamed_Salah_233/gw.csv")
salah_2122_finaldf.to_csv('salah_2122_data.csv', index = False)

# %%
salah_2021_finaldf = get_salah_data('2020-2021', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2020-21/players/Mohamed_Salah_254/gw.csv")
salah_2021_finaldf.to_csv('salah_2021_data.csv')

# %%
salah_1920_finaldf = get_salah_data('2019-2020', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2019-20/players/Mohamed_Salah_191/gw.csv")
salah_1920_finaldf.to_csv('salah_1920_data.csv')

# %%
salah_1819_finaldf = get_salah_data('2018-2019', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2018-19/players/Mohamed_Salah_253/gw.csv")
salah_1819_finaldf.to_csv('salah_1819_data.csv')

# %%
salah_1718_finaldf = get_salah_data('2017-2018', "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2017-18/players/Mohamed_Salah/gw.csv")
salah_1718_finaldf.to_csv('salah_1718_data.csv')

# %%
salah_finaldat = pd.concat([salah_1718_finaldf, salah_1819_finaldf, salah_1920_finaldf, salah_2021_finaldf, salah_2122_finaldf
                            , salah_2223_finaldf, salah_2324_finaldf], join = 'inner', ignore_index = True)
salah_finaldat.to_csv('salah_finaldat.csv')

# %%
#this function just gets the html code that we need to scrape for data, updated version that is not specific to salah 
def get_url_final(code, year_range, category, player):
    base_url = 'https://fbref.com/en/players/{}/matchlogs/{}/c9/{}/{}-Match-Logs'
    url = base_url.format(code, year_range, category, player)
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'lxml')
    html_filtered = soup.find('tbody')
    return(html_filtered)

# %%
#now, we want to modifiy the function above, to allow us to get any players data that we want, not just salah

def get_data(code, year_range, player, fpl_link):
    data_summary = get_url_final(code, year_range, '', player)
    data_passing = get_url_final(code, year_range, 'passing', player)
    data_passingtype = get_url_final(code, year_range, 'passing_types', player)
    data_gca = get_url_final(code, year_range, 'gca', player)
    data_defense = get_url_final(code, year_range, 'defense', player)
    data_possession = get_url_final(code, year_range, 'possession', player)
    
    ################################################################
    #getting the data for the necessary columns
    
    ##### summary data #####
    #misc data 
    date = get_date(data_summary, 'date')
    day = get_dat(data_summary,'dayofweek')
    matchweek = get_matchweek(data_summary, 'round')
    venue = get_dat(data_summary, 'venue')
    result = get_dat(data_summary, 'result')
    team = get_dat(data_summary, 'team')
    opponent = get_dat(data_summary, 'opponent')
    start = get_dat(data_summary, 'game_started')
    position = get_dat(data_summary, 'position')
    mins = get_dat(data_summary, 'minutes')

    #performance data
    goals = get_dat(data_summary, 'goals')
    assist = get_dat(data_summary, 'assists')
    pen_goals = get_dat(data_summary, 'pens_made')
    pen_attempted = get_dat(data_summary, 'pens_att')
    shots = get_dat(data_summary, 'shots')
    sot = get_dat(data_summary, 'shots_on_target')
    yellow = get_dat(data_summary, 'cards_yellow')
    red = get_dat(data_summary, 'cards_red')
    touches = get_dat(data_summary, 'touches')
    tackles = get_dat(data_summary, 'tackles')
    interceptions = get_dat(data_summary, 'interceptions')
    blocks = get_dat(data_summary, 'blocks')

    #expected performance metrics
    xg = get_dat(data_summary, 'xg')
    npxg = get_dat(data_summary, 'npxg')
    xag = get_dat(data_summary, 'xg_assist')

    #shot creating actions
    sca = get_dat(data_summary, 'sca')
    gca = get_dat(data_summary, 'gca')

    #passes
    passes_completed = get_dat(data_summary, 'passes_completed')
    passes_attempted = get_dat(data_summary, 'passes')
    prg_passes = get_dat(data_summary, 'progressive_passes')

    #carries 
    carries = get_dat(data_summary, 'carries')
    prg_carries = get_dat(data_summary, 'progressive_carries')

    #take-ons
    takeon_att = get_dat(data_summary, 'take_ons')
    takeon_suc = get_dat(data_summary, 'take_ons_won')
    
    ##### passing data #####
    #total
    pass_distance = get_dat(data_passing, 'passes_total_distance')
    prg_pass_distance = get_dat(data_passing, 'passes_progressive_distance')

    #short
    short_pass_completed = get_dat(data_passing, 'passes_completed_short')
    short_pass_attempted = get_dat(data_passing, 'passes_short')

    #medium 
    med_pass_completed = get_dat(data_passing, 'passes_completed_medium')
    med_pass_attempted = get_dat(data_passing, 'passes_medium')

    #long
    long_pass_completed = get_dat(data_passing, 'passes_completed_long')
    long_pass_attempted = get_dat(data_passing, 'passes_long')

    #misc
    xa = get_dat(data_passing, 'pass_xa')
    keypass = get_dat(data_passing, 'assisted_shots')
    finalthird_pass = get_dat(data_passing, 'passes_into_final_third')
    penaltyarea_pass = get_dat(data_passing, 'passes_into_penalty_area')
    penaltyarea_cross = get_dat(data_passing, 'crosses_into_penalty_area')
    
    
    ##### passing types data #####
    live_pass = get_dat(data_passingtype, 'passes_live')
    dead_pass = get_dat(data_passingtype, 'passes_dead')
    freekick_pass = get_dat(data_passingtype, 'passes_free_kicks')
    through_balls = get_dat(data_passingtype, 'through_balls')
    switches = get_dat(data_passingtype, 'passes_switches')
    crosses = get_dat(data_passingtype, 'crosses')
    throwin = get_dat(data_passingtype, 'throw_ins')
    corners = get_dat(data_passingtype, 'corner_kicks')
    offside_pass = get_dat(data_passingtype, 'passes_offsides')
    
    
    ##### gca data #####
    #sca types 
    live_sca = get_dat(data_gca, 'sca_passes_live')
    deadball_sca = get_dat(data_gca, 'sca_passes_dead')
    takeons_sca = get_dat(data_gca, 'sca_take_ons')
    shots_sca = get_dat(data_gca, 'sca_shots')
    fouls_sca = get_dat(data_gca, 'sca_fouled')
    defense_sca = get_dat(data_gca, 'sca_defense')

    #gca types 
    live_gca = get_dat(data_gca, 'gca_passes_live')
    deadball_gca = get_dat(data_gca, 'gca_passes_dead')
    takeons_gca = get_dat(data_gca, 'gca_take_ons')
    shots_gca = get_dat(data_gca, 'gca_shots')
    fouls_gca = get_dat(data_gca, 'gca_fouled')
    defense_gca = get_dat(data_gca, 'gca_defense')
    
    
    ##### defensive data ######
    #tackles
    tackles_won = get_dat(data_defense,'tackles_won')
    tackles_def = get_dat(data_defense, 'tackles_def_3rd')
    tackles_mid = get_dat(data_defense, 'tackles_mid_3rd')
    tackles_att = get_dat(data_defense, 'tackles_att_3rd')

    #challenges 
    dribblers_tackled = get_dat(data_defense, 'challenge_tackles')
    dribbles_challenged = get_dat(data_defense, 'challenges')
    challenges_lost = get_dat(data_defense, 'challenges_lost')

    #blocks 
    shots_blocked = get_dat(data_defense, 'blocked_shots')
    pass_blocked = get_dat(data_defense, 'blocked_passes')
    clearances = get_dat(data_defense, 'clearances')
    def_errors = get_dat(data_defense, 'errors')
    
    
    ##### possession data #####
    #touches 
    def_penarea_touches = get_dat(data_possession, 'touches_def_pen_area')
    def_third_touches = get_dat(data_possession, 'touches_def_3rd')
    mid_third_touches = get_dat(data_possession, 'touches_mid_3rd')
    att_third_touches = get_dat(data_possession, 'touches_att_3rd')
    pen_area_touches = get_dat(data_possession, 'touches_att_pen_area')

    #carries
    carry_distance = get_dat(data_possession, 'carries_distance')
    prg_carry_distance = get_dat(data_possession, 'carries_progressive_distance')
    final_third_carries = get_dat(data_possession, 'carries_into_final_third')
    pen_area_carries = get_dat(data_possession, 'carries_into_penalty_area')
    miscontrols = get_dat(data_possession, 'miscontrols')
    dispossesed = get_dat(data_possession, 'dispossessed')

    #receiving 
    pass_received = get_dat(data_possession, 'passes_received')
    prg_pass_received = get_dat(data_possession, 'progressive_passes_received')


    ###########################################################
    #creating dataframe
    df = pd.DataFrame({
        'Date': date,
        'Day': day,
        'Matchweek': matchweek,
        'Venue': venue,
        'Result': result,
        'Team': team,
        'Opponent': opponent, 
        'Start': start, 
        'Position': position,
        'Minutes Played': mins, 
        'Goals': goals, 
        'Assists': assist, 
        'Penalties Scored': pen_goals, 
        'Penalties Attempted': pen_attempted, 
        'Shots': shots, 
        'Shots on Target': sot, 
        'Yellow Cards': yellow, 
        'Red Cards': red, 
        'Touches': touches, 
        'Tackles': tackles,
        'Interceptions': interceptions, 
        'Blocks': blocks, 
        'xG': xg,
        'npxG': npxg,
        'xAG': xag, 
        'Shot Creating Actions': sca, 
        'Goal Creating Actions': gca, 
        'Passes Completed': passes_completed, 
        'Passes Attempted': passes_attempted, 
        'Progressive Passes': prg_passes,
        'Carries': carries, 
        'Progressive Carries': prg_carries, 
        'Take-ons Attempted': takeon_att, 
        'Successful Take-ons': takeon_suc,
        
        'Passing Distance': pass_distance, 
        'Progressive Passing Distance': prg_pass_distance,
        'Short Passes Completed' : short_pass_completed,
        'Short Passes Attempted': short_pass_attempted,
        'Medium Passes Completed': med_pass_completed,
        'Medium Passes Attempted': med_pass_attempted,
        'Long Passes Completed': long_pass_completed,
        'Long Passes Attempted': long_pass_attempted,
        'Expected Assists': xa,
        'Key Passes': keypass,
        'Passes into Final Third': finalthird_pass,
        'Passes into Penalty Area': penaltyarea_pass,
        'Crosses into Penalty Area': penaltyarea_cross,
    
        'Live Pass': live_pass,
        'Dead Pass': dead_pass,
        'Free Kick Pass': freekick_pass,
        'Through Balls': through_balls,
        'Switches': switches,
        'Crosses': crosses,
        'Throw Ins Taken': throwin,
        'Corners Taken': corners,
        'Passes Offside': offside_pass,
    
        'Live SCA': live_sca,
        'Deadball SCA': deadball_sca,
        'Take-on SCA': takeons_sca,
        'Shot SCA': shots_sca,
        'Foul SCA': fouls_sca,
        'Defense SCA': defense_sca,
    
        'Live GCA': live_gca,
        'Deadball GCA': deadball_gca,
        'Take-on GCA': takeons_gca,
        'Shot GCA': shots_gca,
        'Foul GCA': fouls_gca,
        'Defense GCA': defense_gca,
    
        'Tackles Won': tackles_won,
        'Defensive Third Tackles': tackles_def,
        'Middle Third Tackles': tackles_mid,
        'Attacking Third Tackles': tackles_att,
        'Dribblers Tackled': dribblers_tackled,
        'Dribblers Tackled Attempts': dribbles_challenged,
        'Challenges Lost': challenges_lost,
        'Shots Blocked': shots_blocked,
        'Passes Blocked': pass_blocked,
        'Clearances': clearances,
        'Defensive Errors': def_errors,
    
        'Defensive Penalty Area Touches': def_penarea_touches,
        'Defensive Third Touches': def_third_touches,
        'Middle Third Touches': mid_third_touches,
        'Attacking Third Touches': att_third_touches,
        'Penalty Area Touches': pen_area_touches,
        'Carry Distance': carry_distance,
        'Progressive Carry Distance': prg_carry_distance,
        'Final Third Carries': final_third_carries,
        'Carries into Penalty Area': pen_area_carries,
        'Miscontrols': miscontrols,
        'Dispossessed': dispossesed,
        'Passes Received': pass_received,
        'Progressive Passes Received': prg_pass_received
    })
    
    #modifying data types
    df = df.astype({
        'Date': 'datetime64[ns]',
        'Day': 'object',
        'Matchweek': 'int64',
        'Venue': 'object',
        'Result': 'object',
        'Team': 'object',
        'Opponent': 'object', 
        'Start': 'object', 
        'Position': 'object',
        'Minutes Played': 'int64', 
        'Goals': 'int64', 
        'Assists': 'int64', 
        'Penalties Scored': 'int64', 
        'Penalties Attempted': 'int64', 
        'Shots': 'int64', 
        'Shots on Target': 'int64', 
        'Yellow Cards': 'int64', 
        'Red Cards': 'int64', 
        'Touches': 'int64', 
        'Tackles': 'int64',
        'Interceptions': 'int64', 
        'Blocks': 'int64', 
        'xG': 'float64',
        'npxG': 'float64',
        'xAG': 'float64', 
        'Shot Creating Actions': 'int64', 
        'Goal Creating Actions': 'int64', 
        'Passes Completed': 'int64', 
        'Passes Attempted': 'int64', 
        'Progressive Passes': 'int64',
        'Carries': 'int64', 
        'Progressive Carries': 'int64', 
        'Take-ons Attempted': 'int64', 
        'Successful Take-ons': 'int64',
        
        'Short Passes Completed' : 'int64',
        'Short Passes Attempted': 'int64',
        'Medium Passes Completed': 'int64',
        'Medium Passes Attempted': 'int64',
        'Long Passes Completed': 'int64',
        'Long Passes Attempted': 'int64',
        'Expected Assists': 'float64',
        'Key Passes': 'int64',
        'Passes into Final Third': 'int64',
        'Passes into Penalty Area': 'int64',
        'Crosses into Penalty Area': 'int64',
    
        'Live Pass': 'int64',
        'Dead Pass': 'int64',
        'Free Kick Pass': 'int64',
        'Through Balls': 'int64',
        'Switches': 'int64',
        'Crosses': 'int64',
        'Throw Ins Taken': 'int64',
        'Corners Taken': 'int64',
        'Passes Offside': 'int64',
    
        'Live SCA': 'int64',
        'Deadball SCA': 'int64',
        'Take-on SCA': 'int64',
        'Shot SCA': 'int64',
        'Foul SCA': 'int64',
        'Defense SCA': 'int64',
    
        'Live GCA': 'int64',
        'Deadball GCA': 'int64',
        'Take-on GCA': 'int64',
        'Shot GCA': 'int64',
        'Foul GCA': 'int64',
        'Defense GCA': 'int64',
    
        'Tackles Won': 'int64',
        'Defensive Third Tackles': 'int64',
        'Middle Third Tackles': 'int64',
        'Attacking Third Tackles': 'int64',
        'Dribblers Tackled': 'int64',
        'Dribblers Tackled Attempts': 'int64',
        'Challenges Lost': 'int64',
        'Shots Blocked': 'int64',
        'Passes Blocked': 'int64',
        'Clearances': 'int64',
        'Defensive Errors': 'int64',
    
        'Defensive Penalty Area Touches': 'int64',
        'Defensive Third Touches': 'int64',
        'Middle Third Touches': 'int64',
        'Attacking Third Touches': 'int64',
        'Penalty Area Touches': 'int64',
        'Carry Distance': 'float64',
        'Progressive Carry Distance': 'float64',
        'Final Third Carries': 'int64',
        'Carries into Penalty Area': 'int64',
        'Miscontrols': 'int64',
        'Dispossessed': 'int64',
        'Passes Received': 'int64',
        'Progressive Passes Received': 'int64'
    })
    
    #changing date column data type 
    df['Date'] = df['Date'].dt.date
    
    ###############################################################################
    
    #now we want to get the fpl data 
    fpldf= pd.read_csv(fpl_link)

    #some of the columns are duplicated (from the webscraped data), so we want to remove these 
    fpldf = fpldf.drop(['assists', 'expected_assists', 'expected_goal_involvements', 'expected_goals', 'fixture',
                                          'goals_conceded', 'goals_scored', 'penalties_missed', 'penalties_saved', 'red_cards'
                                          ,'team_a_score', 'team_h_score', 'was_home', 'yellow_cards', 'element', 'opponent_team', 'starts'
                                          ,'expected_goals_conceded'], axis=1, 
                       errors = 'ignore')

    #we now want to change the 'kickoff time' feature into a datetime object 
    fpldf['kickoff_time'] = pd.to_datetime(fpldf['kickoff_time'])

    #creating new column, which is just the kickoff date 
    fpldf['kickoff_date'] = fpldf['kickoff_time'].dt.date
    
    finaldf = pd.merge(df, fpldf, left_on='Date', right_on='kickoff_date', how='inner')
    
    return(finaldf)

# %%
jota_2324_finaldf = get_data('178ae8f8', '2023-2024', 'Diogo-Jota',  "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2023-24/players/Diogo_Teixeira%20da%20Silva_294/gw.csv")
jota_2324_finaldf.to_csv('jota_2324_data.csv', index = False)

# %%
jota_2223_finaldf = get_data('178ae8f8', '2022-2023', 'Diogo-Jota',  "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2022-23/players/Diogo_Teixeira%20da%20Silva_288/gw.csv")
jota_2223_finaldf.to_csv('jota_2223_data.csv', index = False)

# %%
jota_2122_finaldf = get_data('178ae8f8', '2021-2022', 'Diogo-Jota',  "https://raw.githubusercontent.com/vaastav/Fantasy-Premier-League/master/data/2021-22/players/Diogo_Jota_240/gw.csv")
jota_2122_finaldf.to_csv('jota_2122_data.csv', index = False)
